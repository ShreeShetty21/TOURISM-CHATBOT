# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreeShetty21/TOURISM-CHATBOT/blob/main/NLP_CHATBOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data of tourist places for different Indian states with their specialties
tourist_places = {
    'Andhra Pradesh': {
        'places': ['Tirupati', 'Visakhapatnam', 'Vijayawada', 'Amaravati', 'Araku Valley'],
        'specialty': {
            'Tirupati': 'Famous for its temples and spiritual significance.',
            'Visakhapatnam': 'Offers beautiful beaches and a serene coastline.',
            'Vijayawada': 'Known for its historical landmarks and cultural sites.',
            'Amaravati': 'Renowned for Buddhist sites and historical significance.',
            'Araku Valley': 'Famous for its scenic beauty and coffee plantations.'
        }
    },
    'Arunachal Pradesh': {
        'places': ['Tawang', 'Itanagar', 'Ziro', 'Bomdila', 'Dirang'],
        'specialty': {
            'Tawang': 'Known for its Buddhist monastery and scenic beauty.',
            'Itanagar': 'Famous for the Ita Fort and Ganga Lake.',
            'Ziro': 'Famous for lush landscapes and music festivals.',
            'Bomdila': 'Renowned for apple orchards and Buddhist monasteries.',
            'Dirang': 'Known for hot springs and natural beauty.'
        }
    },
    'Assam': {
        'places': ['Guwahati', 'Kaziranga National Park', 'Tezpur', 'Jorhat', 'Silchar'],
        'specialty': {
            'Guwahati': 'Known for Kamakhya Temple and Brahmaputra River cruises.',
            'Kaziranga National Park': 'Renowned for one-horned rhinoceros and wildlife.',
            'Tezpur': 'Famous for ancient ruins and historical significance.',
            'Jorhat': 'Known for tea gardens and cultural heritage.',
            'Silchar': 'Renowned for scenic beauty and natural landscapes.'
        }
    },
    'Bihar': {
        'places': ['Patna', 'Bodh Gaya', 'Nalanda', 'Rajgir', 'Vaishali'],
        'specialty': {
            'Patna': 'Famous for historical sites and religious significance.',
            'Bodh Gaya': 'Renowned as a Buddhist pilgrimage site.',
            'Nalanda': 'Known for ancient ruins and the historic Nalanda University.',
            'Rajgir': 'Famous for hot springs and cultural sites.',
            'Vaishali': 'Renowned for historical significance and ancient sites.'
        }
    },
    'Chhattisgarh': {
        'places': ['Raipur', 'Bastar', 'Chitrakoot Falls', 'Bilaspur', 'Jagdalpur'],
        'specialty': {
            'Raipur': 'Famous for cultural sites and industrial significance.',
            'Bastar': 'Known for tribal culture and traditional crafts.',
            'Chitrakoot Falls': 'Renowned for picturesque waterfalls.',
            'Bilaspur': 'Famous for temples and cultural heritage.',
            'Jagdalpur': 'Known for natural beauty and tribal festivals.'
        }
    },
    'Goa': {
        'places': ['Panaji', 'Calangute', 'Dudhsagar Falls', 'Old Goa', 'Anjuna Beach'],
        'specialty': {
            'Panaji': 'The capital city known for its vibrant culture.',
            'Calangute': 'Famous for its beaches and water sports.',
            'Dudhsagar Falls': 'A stunning waterfall amidst lush greenery.',
            'Old Goa': 'Known for its churches, including Basilica of Bom Jesus.',
            'Anjuna Beach': 'Famous for its flea market and vibrant nightlife.'
        }
    },
    'Gujarat': {
        'places': ['Ahmedabad', 'Vadodara', 'Gir National Park', 'Somnath Temple', 'Rann of Kutch'],
        'specialty': {
            'Ahmedabad': 'Known for cultural heritage and Sabarmati Ashram.',
            'Vadodara': 'Famous for palaces and cultural landmarks.',
            'Gir National Park': 'Renowned for Asiatic lions and wildlife.',
            'Somnath Temple': 'A revered Hindu pilgrimage site.',
            'Rann of Kutch': 'Famous for the white salt desert and Rann Utsav.'
        }
    },
    'Haryana': {
        'places': ['Gurugram', 'Faridabad', 'Panipat', 'Kurukshetra', 'Hisar'],
        'specialty': {
            'Gurugram': 'Known for urban development and corporate offices.',
            'Faridabad': 'Famous for industrial development and modern infrastructure.',
            'Panipat': 'Renowned for historical battles and textile industry.',
            'Kurukshetra': 'Historical and religious significance mentioned in the Mahabharata.',
            'Hisar': 'Known for forts and historical monuments.'
        }
    },
    'Himachal Pradesh': {
        'places': ['Shimla', 'Manali', 'Dharamshala', 'Kullu', 'Dalhousie'],
        'specialty': {
            'Shimla': 'Known for colonial architecture and Mall Road.',
            'Manali': 'A popular hill station with adventure activities.',
            'Dharamshala': 'Famous for Tibetan culture and the residence of Dalai Lama.',
            'Kullu': 'Renowned for scenic beauty and Kullu Dussehra.',
            'Dalhousie': 'Known for its picturesque landscapes and British charm.'
        }
    },
    'Jharkhand': {
        'places': ['Ranchi', 'Jamshedpur', 'Bokaro Steel City', 'Hazaribagh', 'Dhanbad'],
        'specialty': {
            'Ranchi': 'Known for waterfalls and scenic beauty.',
            'Jamshedpur': 'Famous for Tata Steel and industrial development.',
            'Bokaro Steel City': 'Renowned for steel plants and industrial significance.',
            'Hazaribagh': 'Known for wildlife and natural beauty.',
            'Dhanbad': 'Famous for coal mines and industrial town.'
        }
    },
    'Karnataka': {
        'places': ['Bangalore', 'Mysore', 'Hampi', 'Coorg', 'Gokarna'],
        'specialty': {
            'Bangalore': 'The tech hub known for gardens and nightlife.',
            'Mysore': 'Famous for palaces, particularly Mysore Palace.',
            'Hampi': 'Renowned for ruins of Vijayanagara Empire.',
            'Coorg': 'Known for coffee plantations and scenic beauty.',
            'Gokarna': 'Famous for beaches and temples.'
        }
    },
    'Kerala': {
        'places': ['Kochi', 'Alleppey', 'Munnar', 'Wayanad', 'Kovalam'],
        'specialty': {
            'Kochi': 'A city with a blend of cultures and famous for Chinese fishing nets.',
            'Alleppey': 'Known for backwater tourism and houseboat stays.',
            'Munnar': 'Famous for tea plantations, Eravikulam National Park, and Anamudi Peak.',
            'Wayanad': 'Renowned for trekking trails, wildlife, and scenic beauty.',
            'Kovalam': 'Famous for its beaches and the Lighthouse Beach.'
        }
    },
    'Madhya Pradesh': {
        'places': ['Bhopal', 'Indore', 'Gwalior', 'Khajuraho', 'Sanchi'],
        'specialty': {
            'Bhopal': 'Known for lakes and historical monuments.',
            'Indore': 'Famous for its food culture and Rajwada Palace.',
            'Gwalior': 'Known for majestic Gwalior Fort and temples.',
            'Khajuraho': 'Famous for its UNESCO-listed erotic sculptures.',
            'Sanchi': 'Renowned for ancient Buddhist monuments.'
        }
    },
    'Maharashtra': {
        'places': ['Mumbai', 'Pune', 'Aurangabad', 'Nashik', 'Lonavala'],
        'specialty': {
            'Mumbai': 'The financial capital known for Bollywood and Marine Drive.',
            'Pune': 'Famous for educational institutes and historical sites.',
            'Aurangabad': 'Renowned for Ajanta and Ellora Caves.',
            'Nashik': 'Known for religious significance and vineyards.',
            'Lonavala': 'Famous for hill station and caves.'
        }
    },
    'Manipur': {
        'places': ['Imphal', 'Loktak Lake', 'Ukhrul', 'Tamenglong', 'Chandel'],
        'specialty': {
            'Imphal': 'Known for cultural heritage and Ima Keithel market.',
            'Loktak Lake': 'The largest freshwater lake in Northeast India.',
            'Ukhrul': 'Renowned for scenic beauty and Shirui Lily.',
            'Tamenglong': 'Known for eco-tourism and Tharon Cave.',
            'Chandel': 'Famous for its scenic landscapes and tribal culture.'
        }
    },
    'Meghalaya': {
        'places': ['Shillong', 'Cherrapunji', 'Tura', 'Jowai', 'Williamnagar'],
        'specialty': {
            'Shillong': 'Known as the Scotland of the East and famous for its music scene.',
            'Cherrapunji': 'One of the wettest places on Earth and famous for living root bridges.',
            'Tura': 'Known for its scenic beauty and peaceful environment.',
            'Jowai': 'Famous for waterfalls and religious sites.',
            'Williamnagar': 'Renowned for natural beauty and wildlife sanctuaries.'
        }
    },
    'Mizoram': {
        'places': ['Aizawl', 'Champhai', 'Lunglei', 'Serchhip', 'Lawngtlai'],
        'specialty': {
            'Aizawl': 'The capital city known for its cultural richness.',
            'Champhai': 'Famous for its landscapes and the Rih Dil Lake.',
            'Lunglei': 'Renowned for its scenic beauty and natural attractions.',
            'Serchhip': 'Known for scenic views and traditional festivals.',
            'Lawngtlai': 'Famous for its natural beauty and Rice Research Station.'
        }
    },
    'Nagaland': {
        'places': ['Kohima', 'Dimapur', 'Mokokchung', 'Wokha', 'Tuensang'],
        'specialty': {
            'Kohima': 'Known for the Hornbill Festival and War Cemetery.',
            'Dimapur': 'Famous for historical sites and markets.',
            'Mokokchung': 'Renowned for its cultural heritage and festivals.',
            'Wokha': 'Known for scenic beauty and Mount Tiyi.',
            'Tuensang': 'Famous for its vibrant culture and Chilise Festival.'
        }
    },
    'Odisha': {
        'places': ['Bhubaneswar', 'Puri', 'Konark', 'Cuttack', 'Sambalpur'],
        'specialty': {
            'Bhubaneswar': 'Known as the Temple City and famous for Lingaraja Temple.',
            'Puri': 'Famous for the Jagannath Temple and Puri Beach.',
            'Konark': 'Renowned for the Sun Temple and architectural brilliance.',
            'Cuttack': 'Known for historical significance and silver filigree work.',
            'Sambalpur': 'Famous for Sambalpuri textiles and Hirakud Dam.'
        }
    },
    'Punjab': {
        'places': ['Amritsar', 'Ludhiana', 'Jalandhar', 'Patiala', 'Pathankot'],
        'specialty': {
            'Amritsar': 'Known for the Golden Temple and the Wagah Border ceremony.',
            'Ludhiana': 'Famous for its industrial significance and shopping markets.',
            'Jalandhar': 'Renowned for its historical sites and religious places.',
            'Patiala': 'Known for forts, palaces, and cultural heritage.',
            'Pathankot': 'Famous for its forts and strategic significance.'
        }
    },
    'Rajasthan': {
        'places': ['Jaipur', 'Udaipur', 'Jaisalmer', 'Ranthambore'],
        'specialty':{'Jaipur is known as the Pink City. ',
                     'Jaisalmer has the famous Jaisalmer Fort.',
                     'Udaipur famous for its Forts and Palaces.',
                     'Ranthambore is famous for largest tiger population.'
        }
        },
    'Sikkim': {
        'places': ['Gangtok', 'Tsomgo Lake', 'Ravangla', 'Pelling', 'Lachung'],
        'specialty': {
            'Gangtok': 'The capital city known for monasteries and scenic beauty.',
            'Tsomgo Lake': 'Renowned for its stunning beauty and yak rides.',
            'Ravangla': 'Famous for the Buddha Park and natural beauty.',
            'Pelling': 'Known for panoramic views of the Himalayas and monasteries.',
            'Lachung': 'Famous for Lachung Gompa and Yumthang Valley.'
        }
    },
    'Tamil Nadu': {
        'places': ['Chennai', 'Madurai', 'Coimbatore', 'Ooty', 'Kanyakumari'],
        'specialty': {
            'Chennai': 'Known for Marina Beach and Kapaleeshwarar Temple.',
            'Madurai': 'Famous for Meenakshi Amman Temple and Thirumalai Nayakkar Palace.',
            'Coimbatore': 'Renowned for its textile industry and temples.',
            'Ooty': 'A popular hill station known for its gardens and Ooty Lake.',
            'Kanyakumari': 'Famous for Vivekananda Rock Memorial and Thiruvalluvar Statue.'
        }
    },
   'Telangana': {
        'places': ['Hyderabad', 'Warangal', 'Nizamabad', 'Karimnagar', 'Khammam'],
        'specialty': {
            'Hyderabad': 'Known for Charminar, Biryani, and historical landmarks.',
            'Warangal': 'Famous for Warangal Fort and Thousand Pillar Temple.',
            'Nizamabad': 'Renowned for Nizamabad Fort and historical significance.',
            'Karimnagar': 'Known for Elgandal Fort and Lower Manair Dam.',
            'Khammam': 'Famous for Khammam Fort and natural beauty.'
        }
    },
    'Tripura': {
        'places': ['Agartala', 'Udaipur', 'Ambassa', 'Kailashahar', 'Belonia'],
        'specialty': {
            'Agartala': 'The capital city known for Ujjayanta Palace and lakes.',
            'Udaipur': 'Famous for Tripura Sundari Temple and lakes.',
            'Ambassa': 'Renowned for its natural beauty and lush greenery.',
            'Kailashahar': 'Known for temples and historical significance.',
            'Belonia': 'Famous for scenic beauty and natural landscapes.'
        }
    },
    'Uttar Pradesh': {
        'places': ['Lucknow', 'Agra', 'Varanasi', 'Allahabad', 'Mathura'],
        'specialty': {
            'Lucknow': 'Known for historical sites and cultural heritage.',
            'Agra': 'Famous for the Taj Mahal, Agra Fort, and Fatehpur Sikri.',
            'Varanasi': 'Renowned for Kashi Vishwanath Temple and Ganges Ghats.',
            'Allahabad': 'Known for Triveni Sangam and historical significance.',
            'Mathura': 'Famous for Krishna Janmasthan Temple and cultural sites.'
        }
    },
    'Uttarakhand': {
        'places': ['Dehradun', 'Nainital', 'Mussoorie', 'Rishikesh', 'Haridwar'],
        'specialty': {
            'Dehradun': 'Known for pleasant climate and institutions like Forest Research Institute.',
            'Nainital': 'Famous for Naini Lake and Naina Devi Temple.',
            'Mussoorie': 'Known as the "Queen of Hills" and famous for Kempty Falls.',
            'Rishikesh': 'Renowned for spiritual significance and adventure sports.',
            'Haridwar': 'Famous for Har Ki Pauri Ghat and Ganga Aarti.'
        }
    },
    'West Bengal': {
        'places': ['Kolkata', 'Darjeeling', 'Digha', 'Howrah', 'Murshidabad'],
        'specialty': {
            'Kolkata': 'Known for vibrant culture and historical sites.',
            'Darjeeling': 'Famous for tea gardens and scenic views of Himalayas.',
            'Digha': 'Renowned for beautiful beaches and seafood.',
            'Howrah': 'Known for the iconic Howrah Bridge and riverside views.',
            'Murshidabad': 'Famous for historical monuments and palaces.'
        }
    }
}



# Function to recommend places based on weather preferences

# Data of tourist places for different Indian states with their specialties (previous data here...)

# Function to ask for weather preferences
# Function to recommend places based on weather preferences


    # Add other weather conditions similarly...

# Function to explore places based on the selected state
# Data of tourist places for different Indian states with their specialties (your entire tourist_places dictionary here...)

# Function to prompt weather preferences
# Data of tourist places for different Indian states with their specialties
# ... (the previous data remains the same)
climate_states = {
    1: ['Kerala', 'Karnataka', 'Tamil Nadu', 'Andhra Pradesh', 'Telangana', 'Goa'],
    2: ['Himachal Pradesh', 'Uttarakhand', 'Jammu and Kashmir', 'Sikkim', 'Arunachal Pradesh', 'Meghalaya', 'Nagaland', 'Manipur', 'Mizoram', 'Tripura'],
    3: ['Rajasthan', 'Gujarat'],
    4: ['Maharashtra', 'Odisha', 'West Bengal'],
    5: ['Punjab', 'Haryana', 'Uttar Pradesh', 'Bihar', 'Jharkhand', 'Chhattisgarh', 'Madhya Pradesh', 'Assam', 'Jharkhand']
}

def display_states(selected_states):
    print("\nHere are the states matching your climate preference:")
    for index, state in enumerate(selected_states, start=1):
        print(f"{index}. 📍 {state}")

def display_places(state):
    print(f"\n🌍 Tourist places in {state}:")
    places = tourist_places[state]['places']
    for index, place in enumerate(places, start=1):
        print(f"   {index}. 🗺️ {place}")

def explore_specialties(chosen_state):
    print("\n🌟 Here are the specialties:")
    for place, specialty in tourist_places[chosen_state]['specialty'].items():
        print(f"- 🌟 {place}: {specialty}")

def main():
    print("👋HEYY THERE!!!!! Welcome\n")
    print("😊I'm a Tourist Bot\n")
    print("✈️I'm here to assist you with your travel plans✈️.\n")
    print("Pack your bags🧳 and get ready 🛫.\n")


    while True:
        print("Select a weather/climate of your choice:\n")
        print("1. 🌴 Tropical")
        print("2. ⛰️ Hill Station")
        print("3. 🏜️ Desert")
        print("4. 🏖️ Coastal")
        print("5. 🌦️ Temperate")
        print("6. ❌ Quit\n")

        climate_choice = int(input("Enter the number corresponding to your preferred climate:\n "))

        if climate_choice == 6:
            print("\n🙏 Thank you for using the travel assistance. Have a great day!\n")
            break

        if climate_choice in climate_states:
            selected_states = climate_states[climate_choice]
            display_states(selected_states)

            state_choice = int(input("Enter the number corresponding to the state you want to explore or 0 to change climate preference: \n"))

            if state_choice == 0:
                print("\n🔄 Let's change your climate preference............\n")
                continue

            elif state_choice in range(1, len(selected_states) + 1):
                chosen_state = selected_states[state_choice - 1]
                display_places(chosen_state)

                specialty_choice = input("\n❓ Would you like to know the specialties of this state? (yes/no): \n")
                if specialty_choice.lower() == 'yes':
                    explore_specialties(chosen_state)

                    continuation = input("\n🔄 Do you want to continue exploring or quit? (continue/quit):\n ")
                    if continuation.lower() == 'quit':
                        print("\n🙏 Thank you for using the travel assistance. Have a great day!\n")
                        break

                elif specialty_choice.lower() == 'no':
                    print("\n🔙 Going back to climate selection...\n")
                    continue

                else:
                    print("❌ Invalid choice. Exiting...")
                    continue

            else:
                print("❌ Invalid choice. Exiting...")
                break

        else:
            print("❌ Invalid choice. Exiting...")
            break

    print("\n🙏 I hope it was helpful. Have a nice day!\n")

if __name__ == "__main__":
    main()
